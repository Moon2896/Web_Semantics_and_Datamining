# %%
import rdflib
from rdflib import Graph, Literal, RDF, RDFS, URIRef, Namespace
from rdflib import Graph
from rdflib.namespace import FOAF, XSD
import pandas as pd
import numpy as np
import re 
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
from owlready2 import *
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %% [markdown]
# # Manipulating the ontology using RDFLIB

# %% [markdown]
# Using Jena develop the following functionalities that:

# %% [markdown]
# Loads the ontology and displays all the Persons (without using queries, without inference).

# %%
#Defining the namespace
nspace = Namespace("Project.rdf")

# Create a Graph
g = Graph()

# Parse in an RDF file hosted locally
g.parse("withpeeps.ttl")

g.namespace_manager.bind("nl",nspace)

# Loop through each triple in the graph (subj, pred, obj)
for subj, pred, obj in g:
    # Check if there is at least one triple in the Graph
    if (subj, pred, obj) not in g:
       raise Exception("It better be!")

# Print the number of "triples" in the Graph
print(f"Graph g has {len(g)} statements.")

# Print out the entire Graph in the RDF Turtle format
print(g.serialize(format="n3"))
# Out:
# Graph g has 19947 statements.
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix webSem: <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem> a owl:Ontology ;
#     owl:versionInfo "" .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#'83> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Biography",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "7.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:DeepikaPadukone,
#         webSem:RanveerSingh,
#         webSem:TahirRajBhasin ;
#     webSem:language "Hindi, English" ;
#     webSem:overview "On June 25, 1983, the Lord's Cricket Ground witnessed 14 men beat the two times World Champions West Indies, putting India back onto the cricket world stage." ;
#     webSem:rated "N/A" ;
#     webSem:title "'83" ;
#     webSem:wasDirectedBy webSem:SanjayPuranSinghChauhan,
#         webSem:SumitArora,
#         webSem:VasanBala ;
#     webSem:wasWrittenBy webSem:SanjayPuranSinghChauhan,
#         webSem:SumitArora,
#         webSem:VasanBala ;
#     webSem:year "2021"^^xsd:int .
#
# webSem:12AngryMen a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Crime",
#         "Drama" ;
#     webSem:imdbRating "9.0"^^xsd:float ;
#     webSem:isPlayedBy webSem:HenryFonda,
#         webSem:LeeJ.Cobb,
#         webSem:MartinBalsam ;
#     webSem:language "English" ;
#     webSem:overview "The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict." ;
#     webSem:rated "Approved" ;
#     webSem:title "12 Angry Men" ;
#     webSem:wasDirectedBy webSem:ReginaldRose ;
#     webSem:wasWrittenBy webSem:ReginaldRose ;
#     webSem:year "1957"^^xsd:int .
#
# webSem:12Monkeys a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Mystery",
#         "Sci-Fi",
#         "Thriller" ;
#     webSem:imdbRating "8.0"^^xsd:float ;
#     webSem:isPlayedBy webSem:BradPitt,
#         webSem:BruceWillis,
#         webSem:MadeleineStowe ;
#     webSem:language "English, French, Latin, Spanish" ;
#     webSem:overview "In a future world devastated by disease, a convict is sent back in time to gather information about the man-made virus that wiped out most of the human population on the planet." ;
#     webSem:rated "R" ;
#     webSem:title "12 Monkeys" ;
#     webSem:wasDirectedBy webSem:ChrisMarker,
#         webSem:DavidWebbPeoples,
#         webSem:JanetPeoples ;
#     webSem:wasWrittenBy webSem:ChrisMarker,
#         webSem:DavidWebbPeoples,
#         webSem:JanetPeoples ;
#     webSem:year "1995"^^xsd:int .
#
# webSem:12YearsaSlave a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States, United Kingdom" ;
#     webSem:genre "Biography",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChiwetelEjiofor,
#         webSem:MichaelFassbender,
#         webSem:MichaelKennethWilliams ;
#     webSem:language "English" ;
#     webSem:overview "In the antebellum United States, Solomon Northup, a free black man from upstate New York, is abducted and sold into slavery." ;
#     webSem:rated "R" ;
#     webSem:title "12 Years a Slave" ;
#     webSem:wasDirectedBy webSem:JohnRidley,
#         webSem:SolomonNorthup ;
#     webSem:wasWrittenBy webSem:JohnRidley,
#         webSem:SolomonNorthup ;
#     webSem:year "2013"^^xsd:int .
#
# webSem:1917 a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom, United States, India, Spain" ;
#     webSem:genre "Action",
#         "Drama",
#         "War" ;
#     webSem:imdbRating "8.2"^^xsd:float ;
#     webSem:isPlayedBy webSem:DanielMays,
#         webSem:Dean-CharlesChapman,
#         webSem:GeorgeMacKay ;
#     webSem:language "English, French, German" ;
#     webSem:overview "April 6th, 1917. As an infantry battalion assembles to wage war deep in enemy territory, two soldiers are assigned to race against time and deliver a message that will stop 1,600 men from walking straight into a deadly trap." ;
#     webSem:rated "R" ;
#     webSem:title "1917" ;
#     webSem:wasDirectedBy webSem:KrystyWilson-Cairns,
#         webSem:SamMendes ;
#     webSem:wasWrittenBy webSem:KrystyWilson-Cairns,
#         webSem:SamMendes ;
#     webSem:year "2019"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#2001:ASpaceOdyssey> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom, United States" ;
#     webSem:genre "Adventure",
#         "Sci-Fi" ;
#     webSem:imdbRating "8.3"^^xsd:float ;
#     webSem:isPlayedBy webSem:GaryLockwood,
#         webSem:KeirDullea,
#         webSem:WilliamSylvester ;
#     webSem:language "English, Russian, French" ;
#     webSem:overview "After uncovering a mysterious artifact buried beneath the Lunar surface, a spacecraft is sent to Jupiter to find its origins - a spacecraft manned by two men and the supercomputer H.A.L. 9000." ;
#     webSem:rated "G" ;
#     webSem:title "2001: A Space Odyssey" ;
#     webSem:wasDirectedBy webSem:ArthurC.Clarke,
#         webSem:StanleyKubrick ;
#     webSem:wasWrittenBy webSem:ArthurC.Clarke,
#         webSem:StanleyKubrick ;
#     webSem:year "1968"^^xsd:int .
#
# webSem:28DaysLater a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom" ;
#     webSem:genre "Drama",
#         "Horror",
#         "Sci-Fi" ;
#     webSem:imdbRating "7.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChristopherEccleston,
#         webSem:CillianMurphy,
#         webSem:NaomieHarris ;
#     webSem:language "English, Spanish" ;
#     webSem:overview "Four weeks after a mysterious, incurable virus spreads throughout the UK, a handful of survivors try to find sanctuary." ;
#     webSem:rated "R" ;
#     webSem:title "28 Days Later" ;
#     webSem:wasDirectedBy webSem:AlexGarland ;
#     webSem:wasWrittenBy webSem:AlexGarland ;
#     webSem:year "2002"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#3:10toYuma> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Action",
#         "Crime",
#         "Drama" ;
#     webSem:imdbRating "7.7"^^xsd:float ;
#     webSem:isPlayedBy webSem:BenFoster,
#         webSem:ChristianBale,
#         webSem:RussellCrowe ;
#     webSem:language "English, Chinese" ;
#     webSem:overview "A small-time rancher agrees to hold a captured outlaw who's awaiting a train to go to court in Yuma. A battle of wills ensues as the outlaw tries to psych out the rancher." ;
#     webSem:rated "R" ;
#     webSem:title "3:10 to Yuma" ;
#     webSem:wasDirectedBy webSem:DerekHaas,
#         webSem:HalstedWelles,
#         webSem:MichaelBrandt ;
#     webSem:wasWrittenBy webSem:DerekHaas,
#         webSem:HalstedWelles,
#         webSem:MichaelBrandt ;
#     webSem:year "2007"^^xsd:int .
#
# webSem:3Idiots a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Comedy",
#         "Drama" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:AamirKhan,
#         webSem:Madhavan,
#         webSem:MonaSingh ;
#     webSem:language "Hindi, English" ;
#     webSem:overview "Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them \"idiots\"." ;
#     webSem:rated "PG-13" ;
#     webSem:title "3 Idiots" ;
#     webSem:wasDirectedBy webSem:AbhijatJoshi,
#         webSem:RajkumarHirani,
#         webSem:VidhuVinodChopra ;
#     webSem:wasWrittenBy webSem:AbhijatJoshi,
#         webSem:RajkumarHirani,
#         webSem:VidhuVinodChopra ;
#     webSem:year "2009"^^xsd:int .
#
# webSem:42 a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Biography",
#         "Drama",
#         "Sport" ;
#     webSem:imdbRating "7.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChadwickBoseman,
#         webSem:HarrisonFord,
#         webSem:T.R.Knight ;
#     webSem:language "English" ;
#     webSem:overview "In 1947, Jackie Robinson becomes the first African-American to play in Major League Baseball in the modern era when he was signed by the Brooklyn Dodgers and faces considerable racism in the process." ;
#     webSem:rated "PG-13" ;
#     webSem:title "42" ;
#     webSem:wasDirectedBy webSem:BrianHelgeland ;
#     webSem:wasWrittenBy webSem:BrianHelgeland ;
#     webSem:year "2013"^^xsd:int .
#
# webSem:777Charlie a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Adventure",
#         "Comedy",
#         "Drama" ;
#     webSem:imdbRating "8.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:Charlie,
#         webSem:RakshitShetty,
#         webSem:SangeethaSringeri ;
#     webSem:language "Kannada" ;
#     webSem:overview "Dharma is stuck in a rut with his negative and lonely lifestyle and spends each day in the comfort of his loneliness. A pup named Charlie enters his life and gives him a new perspective towards it." ;
#     webSem:rated "N/A" ;
#     webSem:title "777 Charlie" ;
#     webSem:wasDirectedBy webSem:K.N.VijayKumar,
#         webSem:KiranrajK,
#         webSem:SatheeshMuthukulam ;
#     webSem:wasWrittenBy webSem:K.N.VijayKumar,
#         webSem:KiranrajK,
#         webSem:SatheeshMuthukulam ;
#     webSem:year "2022"^^xsd:int .
#
# webSem:96 a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Drama",
#         "Romance" ;
#     webSem:imdbRating "8.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:AdithyaBhaskar,
#         webSem:TrishaKrishnan,
#         webSem:VijaySethupathi ;
#     webSem:language "Tamil" ;
#     webSem:overview "Two high school sweethearts meet at a reunion after 22 years and reminisce about their past." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "96" ;
#     webSem:wasDirectedBy webSem:C.PremKumar,
#         webSem:CharuGupta ;
#     webSem:wasWrittenBy webSem:C.PremKumar,
#         webSem:CharuGupta ;
#     webSem:year "2018"^^xsd:int .
#
# webSem:ABeautifulMind a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Biography",
#         "Drama" ;
#     webSem:imdbRating "8.2"^^xsd:float ;
#     webSem:isPlayedBy webSem:EdHarris,
#         webSem:JenniferConnelly,
#         webSem:RussellCrowe ;
#     webSem:language "English" ;
#     webSem:overview "After John Nash, a brilliant but asocial mathematician, accepts secret work in cryptography, his life takes a turn for the nightmarish." ;
#     webSem:rated "PG-13" ;
#     webSem:title "A Beautiful Mind" ;
#     webSem:wasDirectedBy webSem:AkivaGoldsman,
#         webSem:SylviaNasar ;
#     webSem:wasWrittenBy webSem:AkivaGoldsman,
#         webSem:SylviaNasar ;
#     webSem:year "2001"^^xsd:int .
#
# webSem:AClockworkOrange a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom, United States" ;
#     webSem:genre "Crime",
#         "Sci-Fi" ;
#     webSem:imdbRating "8.3"^^xsd:float ;
#     webSem:isPlayedBy webSem:MalcolmMcDowell,
#         webSem:MichaelBates,
#         webSem:PatrickMagee ;
#     webSem:language "English" ;
#     webSem:overview "In the future, a sadistic gang leader is imprisoned and volunteers for a conduct-aversion experiment, but it doesn't go as planned." ;
#     webSem:rated "X" ;
#     webSem:title "A Clockwork Orange" ;
#     webSem:wasDirectedBy webSem:AnthonyBurgess,
#         webSem:StanleyKubrick ;
#     webSem:wasWrittenBy webSem:AnthonyBurgess,
#         webSem:StanleyKubrick ;
#     webSem:year "1971"^^xsd:int .
#
# webSem:AFistfulofDollars a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Italy, Spain, West Germany" ;
#     webSem:genre "Action",
#         "Drama",
#         "Western" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:ClintEastwood,
#         webSem:GianMariaVolontè,
#         webSem:MarianneKoch ;
#     webSem:language "Italian, Spanish, Persian" ;
#     webSem:overview "A wandering gunfighter plays two rival families against each other in a town torn apart by greed, pride, and revenge." ;
#     webSem:rated "R" ;
#     webSem:title "A Fistful of Dollars" ;
#     webSem:wasDirectedBy webSem:AdrianoBolzoni,
#         webSem:MarkLowell,
#         webSem:VíctorAndrésCatena ;
#     webSem:wasWrittenBy webSem:AdrianoBolzoni,
#         webSem:MarkLowell,
#         webSem:VíctorAndrésCatena ;
#     webSem:year "1964"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AHardDay'sNight> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom" ;
#     webSem:genre "Comedy",
#         "Musical" ;
#     webSem:imdbRating "7.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:GeorgeHarrison,
#         webSem:JohnLennon,
#         webSem:PaulMcCartney ;
#     webSem:language "English, German, French" ;
#     webSem:overview "Over two \"typical\" days in the life of The Beatles, the boys struggle to keep themselves and Sir Paul McCartney's mischievous grandfather in check while preparing for a live TV performance." ;
#     webSem:rated "G" ;
#     webSem:title "A Hard Day's Night" ;
#     webSem:wasDirectedBy webSem:AlunOwen ;
#     webSem:wasWrittenBy webSem:AlunOwen ;
#     webSem:year "1964"^^xsd:int .
#
# webSem:ALeagueofTheirOwn a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Comedy",
#         "Drama",
#         "Sport" ;
#     webSem:imdbRating "7.3"^^xsd:float ;
#     webSem:isPlayedBy webSem:GeenaDavis,
#         webSem:LoriPetty,
#         webSem:TomHanks ;
#     webSem:language "English" ;
#     webSem:overview "Two sisters join the first female professional baseball league and struggle to help it succeed amid their own growing rivalry." ;
#     webSem:rated "PG" ;
#     webSem:title "A League of Their Own" ;
#     webSem:wasDirectedBy webSem:KellyCandaele,
#         webSem:KimWilson,
#         webSem:LowellGanz ;
#     webSem:wasWrittenBy webSem:KellyCandaele,
#         webSem:KimWilson,
#         webSem:LowellGanz ;
#     webSem:year "1992"^^xsd:int .
#
# webSem:AManforAllSeasons a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "N/A" ;
#     webSem:genre "Biography",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "7.7"^^xsd:float ;
#     webSem:isPlayedBy webSem:PaulScofield,
#         webSem:RobertShaw,
#         webSem:WendyHiller ;
#     webSem:language "English, Latin, Spanish, French" ;
#     webSem:overview "The story of Sir Thomas More, who stood up to King Henry VIII when the King rejected the Roman Catholic Church to obtain a divorce and remarry." ;
#     webSem:rated "G" ;
#     webSem:title "A Man for All Seasons" ;
#     webSem:wasDirectedBy webSem:RobertBolt ;
#     webSem:wasWrittenBy webSem:RobertBolt ;
#     webSem:year "1966"^^xsd:int .
#
# webSem:ANightattheOpera a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Comedy",
#         "Music",
#         "Musical" ;
#     webSem:imdbRating "7.8"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChicoMarx,
#         webSem:GrouchoMarx,
#         webSem:HarpoMarx ;
#     webSem:language "English, Italian" ;
#     webSem:overview "A sly business manager and the wacky friends of two opera singers in Italy help them achieve success in America while humiliating their stuffy and snobbish enemies." ;
#     webSem:rated "Passed" ;
#     webSem:title "A Night at the Opera" ;
#     webSem:wasDirectedBy webSem:GeorgeS.Kaufman,
#         webSem:JamesKevinMcGuinness,
#         webSem:MorrieRyskind ;
#     webSem:wasWrittenBy webSem:GeorgeS.Kaufman,
#         webSem:JamesKevinMcGuinness,
#         webSem:MorrieRyskind ;
#     webSem:year "1935"^^xsd:int .
#
# webSem:AQuietPlace a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "Horror",
#         "Sci-Fi" ;
#     webSem:imdbRating "7.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:EmilyBlunt,
#         webSem:JohnKrasinski,
#         webSem:MillicentSimmonds ;
#     webSem:language "American Sign , English" ;
#     webSem:overview "In a post-apocalyptic world, a family is forced to live in silence while hiding from monsters with ultra-sensitive hearing." ;
#     webSem:rated "PG-13" ;
#     webSem:title "A Quiet Place" ;
#     webSem:wasDirectedBy webSem:BryanWoods,
#         webSem:JohnKrasinski,
#         webSem:ScottBeck ;
#     webSem:wasWrittenBy webSem:BryanWoods,
#         webSem:JohnKrasinski,
#         webSem:ScottBeck ;
#     webSem:year "2018"^^xsd:int .
#
# webSem:ASeparation a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Iran, France, Australia" ;
#     webSem:genre "Drama" ;
#     webSem:imdbRating "8.3"^^xsd:float ;
#     webSem:isPlayedBy webSem:LeilaHatami,
#         webSem:PaymanMaadi,
#         webSem:SarehBayat ;
#     webSem:language "Persian" ;
#     webSem:overview "A married couple are faced with a difficult decision - to improve the life of their child by moving to another country or to stay in Iran and look after a deteriorating parent who has Alzheimer's disease." ;
#     webSem:rated "PG-13" ;
#     webSem:title "A Separation" ;
#     webSem:wasDirectedBy webSem:AsgharFarhadi ;
#     webSem:wasWrittenBy webSem:AsgharFarhadi ;
#     webSem:year "2011"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ASilentVoice:TheMovie> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Japan" ;
#     webSem:genre "Animation",
#         "Drama" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:AoiYûki,
#         webSem:MiyuIrino,
#         webSem:SaoriHayami ;
#     webSem:language "Japanese, Japanese Sign " ;
#     webSem:overview "A young man is ostracized by his classmates after he bullies a deaf girl to the point where she moves away. Years later, he sets off on a path for redemption." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "A Silent Voice: The Movie" ;
#     webSem:wasDirectedBy webSem:KiyoshiShigematsu,
#         webSem:ReikoYoshida,
#         webSem:YoshitokiOima ;
#     webSem:wasWrittenBy webSem:KiyoshiShigematsu,
#         webSem:ReikoYoshida,
#         webSem:YoshitokiOima ;
#     webSem:year "2016"^^xsd:int .
#
# webSem:AStarIsBorn a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "Music",
#         "Romance" ;
#     webSem:imdbRating "7.6"^^xsd:float ;
#     webSem:isPlayedBy webSem:BradleyCooper,
#         webSem:LadyGaga,
#         webSem:SamElliott ;
#     webSem:language "English, French" ;
#     webSem:overview "A musician helps a young singer find fame as age and alcoholism send his own career into a downward spiral." ;
#     webSem:rated "R" ;
#     webSem:title "A Star Is Born" ;
#     webSem:wasDirectedBy webSem:BradleyCooper,
#         webSem:EricRoth,
#         webSem:WillFetters ;
#     webSem:wasWrittenBy webSem:BradleyCooper,
#         webSem:EricRoth,
#         webSem:WillFetters ;
#     webSem:year "2018"^^xsd:int .
#
# webSem:ATaxiDriver a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "South Korea" ;
#     webSem:genre "Action",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:Hae-JinYoo,
#         webSem:SongKang-ho,
#         webSem:ThomasKretschmann ;
#     webSem:language "German, Japanese, Korean, English" ;
#     webSem:overview "A widowed father and taxi driver who drives a German reporter from Seoul to Gwangju to cover the 1980 uprising, soon finds himself regretting his decision after being caught in the violence around him." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "A Taxi Driver" ;
#     webSem:wasDirectedBy webSem:Yu-naEom ;
#     webSem:wasWrittenBy webSem:Yu-naEom ;
#     webSem:year "2017"^^xsd:int .
#
# webSem:AWednesday a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Action",
#         "Crime",
#         "Drama" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:AnupamKher,
#         webSem:NaseeruddinShah,
#         webSem:VeerendraSaxena ;
#     webSem:language "Hindi, Urdu" ;
#     webSem:overview "A retiring police officer reminisces about the most astounding day of his career. About a case that was never filed but continues to haunt him in his memories - the case of a man and a Wednesday." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "A Wednesday" ;
#     webSem:wasDirectedBy webSem:NeerajPandey ;
#     webSem:wasWrittenBy webSem:NeerajPandey ;
#     webSem:year "2008"^^xsd:int .
#
# webSem:AWomanUndertheInfluence a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "Romance" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:FredDraper,
#         webSem:GenaRowlands,
#         webSem:PeterFalk ;
#     webSem:language "English, Italian" ;
#     webSem:overview "Although wife and mother Mabel is loved by her husband Nick, her mental illness places a strain on the marriage." ;
#     webSem:rated "R" ;
#     webSem:title "A Woman Under the Influence" ;
#     webSem:wasDirectedBy webSem:JohnCassavetes ;
#     webSem:wasWrittenBy webSem:JohnCassavetes ;
#     webSem:year "1974"^^xsd:int .
#
# webSem:AbbasAlibhaiBurmawalla a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Abbas Alibhai Burmawalla" .
#
# webSem:AceintheHole a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "Film-Noir" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:JanSterling,
#         webSem:KirkDouglas,
#         webSem:RobertArthur ;
#     webSem:language "English, Spanish, Latin" ;
#     webSem:overview "A frustrated former big-city journalist now stuck working for an Albuquerque newspaper exploits a story about a man trapped in a cave to rekindle his career, but the situation quickly escalates into an out-of-control circus." ;
#     webSem:rated "Approved" ;
#     webSem:title "Ace in the Hole" ;
#     webSem:wasDirectedBy webSem:BillyWilder,
#         webSem:LesserSamuels,
#         webSem:WalterNewman ;
#     webSem:wasWrittenBy webSem:BillyWilder,
#         webSem:LesserSamuels,
#         webSem:WalterNewman ;
#     webSem:year "1951"^^xsd:int .
#
# webSem:Actor a owl:Class ;
#     rdfs:subClassOf webSem:Person ;
#     owl:equivalentClass [ a owl:Class ;
#             owl:intersectionOf ( webSem:Person [ a owl:Restriction ;
#                         owl:onProperty webSem:isActorOf ;
#                         owl:someValuesFrom webSem:Movie ] ) ] .
#
# webSem:AdrianMolina a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Adrian Molina" .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Aguirre,theWrathofGod> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "West Germany, Mexico" ;
#     webSem:genre "Action",
#         "Adventure",
#         "Biography" ;
#     webSem:imdbRating "7.8"^^xsd:float ;
#     webSem:isPlayedBy webSem:HelenaRojo,
#         webSem:KlausKinski,
#         webSem:RuyGuerra ;
#     webSem:language "German, Quechua, Spanish" ;
#     webSem:overview "In the 16th century, the ruthless and insane Don Lope de Aguirre leads a Spanish expedition in search of El Dorado." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "Aguirre, the Wrath of God" ;
#     webSem:wasDirectedBy webSem:WernerHerzog ;
#     webSem:wasWrittenBy webSem:WernerHerzog ;
#     webSem:year "1972"^^xsd:int .
#
# webSem:Airlift a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "N/A" ;
#     webSem:genre "Action",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:AkshayKumar,
#         webSem:KumudMishra,
#         webSem:NimratKaur ;
#     webSem:language "Hindi" ;
#     webSem:overview "When Iraq invades Kuwait in August 1990, a callous Indian businessman becomes the spokesperson for more than 170,000 stranded countrymen." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "Airlift" ;
#     webSem:wasDirectedBy webSem:RajaMenon,
#         webSem:RiteshShah,
#         webSem:SonuSinha ;
#     webSem:wasWrittenBy webSem:RajaMenon,
#         webSem:RiteshShah,
#         webSem:SonuSinha ;
#     webSem:year "2016"^^xsd:int .
#
# webSem:Akira a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Japan" ;
#     webSem:genre "Action",
#         "Animation",
#         "Drama" ;
#     webSem:imdbRating "8.0"^^xsd:float ;
#     webSem:isPlayedBy webSem:MamiKoyama,
#         webSem:MitsuoIwata,
#         webSem:NozomuSasaki ;
#     webSem:language "Japanese" ;
#     webSem:overview "A secret military project endangers Neo-Tokyo when it turns a biker gang member into a rampaging psychic psychopath who can only be stopped by a teenager, his gang of biker friends and a group of psychics." ;
#     webSem:rated "R" ;
#     webSem:title "Akira" ;
#     webSem:wasDirectedBy webSem:IzôHashimoto,
#         webSem:KatsuhiroÔtomo ;
#     webSem:wasWrittenBy webSem:IzôHashimoto,
#         webSem:KatsuhiroÔtomo ;
#     webSem:year "1988"^^xsd:int .
#
# webSem:Aladdin a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Adventure",
#         "Animation",
#         "Comedy" ;
#     webSem:imdbRating "8.0"^^xsd:float ;
#     webSem:isPlayedBy webSem:LindaLarkin,
#         webSem:RobinWilliams,
#         webSem:ScottWeinger ;
#     webSem:language "English" ;
#     webSem:overview "A kindhearted street urchin and a power-hungry Grand Vizier vie for a magic lamp that has the power to make their deepest wishes come true." ;
#     webSem:rated "G" ;
#     webSem:title "Aladdin" ;
#     webSem:wasDirectedBy webSem:JohnMusker,
#         webSem:RonClements,
#         webSem:TedElliott ;
#     webSem:wasWrittenBy webSem:JohnMusker,
#         webSem:RonClements,
#         webSem:TedElliott ;
#     webSem:year "1992"^^xsd:int .
#
# webSem:AlanJ.Pakula a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Alan J. Pakula" .
#
# webSem:AlanParker a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Alan Parker" .
#
# webSem:AlexProyas a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Alex Proyas" .
#
# webSem:AlfonsoCuarón a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Alfonso Cuarón" .
#
# webSem:Alien a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom, United States" ;
#     webSem:genre "Horror",
#         "Sci-Fi" ;
#     webSem:imdbRating "8.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:JohnHurt,
#         webSem:SigourneyWeaver,
#         webSem:TomSkerritt ;
#     webSem:language "English" ;
#     webSem:overview "The crew of a commercial spacecraft encounter a deadly lifeform after investigating an unknown transmission." ;
#     webSem:rated "R" ;
#     webSem:title "Alien" ;
#     webSem:wasDirectedBy <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanO'Bannon>,
#         webSem:RonaldShusett ;
#     webSem:wasWrittenBy <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanO'Bannon>,
#         webSem:RonaldShusett ;
#     webSem:year "1979"^^xsd:int .
#
# webSem:Aliens a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom, United States" ;
#     webSem:genre "Action",
#         "Adventure",
#         "Sci-Fi" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:CarrieHenn,
#         webSem:MichaelBiehn,
#         webSem:SigourneyWeaver ;
#     webSem:language "English, Spanish" ;
#     webSem:overview "Decades after surviving the Nostromo incident, Ellen Ripley is sent out to re-establish contact with a terraforming colony, but finds herself battling the Alien Queen and her offspring." ;
#     webSem:rated "R" ;
#     webSem:title "Aliens" ;
#     webSem:wasDirectedBy webSem:DavidGiler,
#         webSem:JamesCameron,
#         webSem:WalterHill ;
#     webSem:wasWrittenBy webSem:DavidGiler,
#         webSem:JamesCameron,
#         webSem:WalterHill ;
#     webSem:year "1986"^^xsd:int .
#
# webSem:AllAboutEve a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama" ;
#     webSem:imdbRating "8.2"^^xsd:float ;
#     webSem:isPlayedBy webSem:AnneBaxter,
#         webSem:BetteDavis,
#         webSem:GeorgeSanders ;
#     webSem:language "English, French" ;
#     webSem:overview "A seemingly timid but secretly ruthless ingénue insinuates herself into the lives of an aging Broadway star and her circle of theater friends." ;
#     webSem:rated "Passed" ;
#     webSem:title "All About Eve" ;
#     webSem:wasDirectedBy webSem:JosephL.Mankiewicz,
#         webSem:MaryOrr ;
#     webSem:wasWrittenBy webSem:JosephL.Mankiewicz,
#         webSem:MaryOrr ;
#     webSem:year "1950"^^xsd:int .
#
# webSem:AllThatJazz a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "Music",
#         "Musical" ;
#     webSem:imdbRating "7.8"^^xsd:float ;
#     webSem:isPlayedBy webSem:AnnReinking,
#         webSem:JessicaLange,
#         webSem:RoyScheider ;
#     webSem:language "English, Spanish" ;
#     webSem:overview "Director/choreographer Bob Fosse tells his own life story as he details the sordid career of Joe Gideon, a womanizing, drug-using dancer." ;
#     webSem:rated "R" ;
#     webSem:title "All That Jazz" ;
#     webSem:wasDirectedBy webSem:BobFosse,
#         webSem:RobertAlanAurthur ;
#     webSem:wasWrittenBy webSem:BobFosse,
#         webSem:RobertAlanAurthur ;
#     webSem:year "1979"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AllthePresident'sMen> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "History",
#         "Thriller" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:DustinHoffman,
#         webSem:JackWarden,
#         webSem:RobertRedford ;
#     webSem:language "English, Spanish" ;
#     webSem:overview "\"The Washington Post\" reporters Bob Woodward and Carl Bernstein uncover the details of the Watergate scandal that leads to President Richard Nixon's resignation." ;
#     webSem:rated "PG" ;
#     webSem:title "All the President's Men" ;
#     webSem:wasDirectedBy webSem:BobWoodward,
#         webSem:CarlBernstein,
#         webSem:WilliamGoldman ;
#     webSem:wasWrittenBy webSem:BobWoodward,
#         webSem:CarlBernstein,
#         webSem:WilliamGoldman ;
#     webSem:year "1976"^^xsd:int .
#
# webSem:AlmostFamous a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Adventure",
#         "Comedy",
#         "Drama" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:BillyCrudup,
#         webSem:KateHudson,
#         webSem:PatrickFugit ;
#     webSem:language "English, French" ;
#     webSem:overview "A high-school boy in the early 1970s is given the chance to write a story for Rolling Stone magazine about an up-and-coming rock band as he accompanies them on their concert tour." ;
#     webSem:rated "R" ;
#     webSem:title "Almost Famous" ;
#     webSem:wasDirectedBy webSem:CameronCrowe ;
#     webSem:wasWrittenBy webSem:CameronCrowe ;
#     webSem:year "2000"^^xsd:int .
#
# webSem:Amadeus a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States, France, Italy" ;
#     webSem:genre "Biography",
#         "Drama",
#         "Music" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:ElizabethBerridge,
#         webSem:F.MurrayAbraham,
#         webSem:TomHulce ;
#     webSem:language "English, Italian, Latin, German, French" ;
#     webSem:overview "The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporaneous composer who was deeply jealous of Mozart's talent and claimed to have murdered him." ;
#     webSem:rated "PG" ;
#     webSem:title "Amadeus" ;
#     webSem:wasDirectedBy webSem:PeterShaffer,
#         webSem:ZdenekMahler ;
#     webSem:wasWrittenBy webSem:PeterShaffer,
#         webSem:ZdenekMahler ;
#     webSem:year "1984"^^xsd:int .
#
# webSem:AmericanBeauty a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:AnnetteBening,
#         webSem:KevinSpacey,
#         webSem:ThoraBirch ;
#     webSem:language "English" ;
#     webSem:overview "A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend." ;
#     webSem:rated "R" ;
#     webSem:title "American Beauty" ;
#     webSem:wasDirectedBy webSem:AlanBall ;
#     webSem:wasWrittenBy webSem:AlanBall ;
#     webSem:year "1999"^^xsd:int .
#
# webSem:AmericanHistoryX a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Crime",
#         "Drama" ;
#     webSem:imdbRating "8.5"^^xsd:float ;
#     webSem:isPlayedBy <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#BeverlyD'Angelo>,
#         webSem:EdwardFurlong,
#         webSem:EdwardNorton ;
#     webSem:language "English" ;
#     webSem:overview "A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did." ;
#     webSem:rated "R" ;
#     webSem:title "American History X" ;
#     webSem:wasDirectedBy webSem:DavidMcKenna ;
#     webSem:wasWrittenBy webSem:DavidMcKenna ;
#     webSem:year "1998"^^xsd:int .
#
# webSem:AmericanPsycho a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States, Canada" ;
#     webSem:genre "Crime",
#         "Drama",
#         "Horror" ;
#     webSem:imdbRating "7.6"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChristianBale,
#         webSem:JoshLucas,
#         webSem:JustinTheroux ;
#     webSem:language "English, Spanish, Cantonese" ;
#     webSem:overview "A wealthy New York City investment banking executive, Patrick Bateman, hides his alternate psychopathic ego from his co-workers and friends as he delves deeper into his violent, hedonistic fantasies." ;
#     webSem:rated "R" ;
#     webSem:title "American Psycho" ;
#     webSem:wasDirectedBy webSem:BretEastonEllis,
#         webSem:GuinevereTurner,
#         webSem:MaryHarron ;
#     webSem:wasWrittenBy webSem:BretEastonEllis,
#         webSem:GuinevereTurner,
#         webSem:MaryHarron ;
#     webSem:year "2000"^^xsd:int .
#
# webSem:AmitabhRezaChowdhury a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Amitabh Reza Chowdhury" .
#
# webSem:AmoresPerros a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Mexico" ;
#     webSem:genre "Drama",
#         "Thriller" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:EmilioEchevarría,
#         webSem:GaelGarcíaBernal,
#         webSem:GoyaToledo ;
#     webSem:language "Spanish" ;
#     webSem:overview "A horrific car accident connects three stories, each involving characters dealing with loss, regret, and life's harsh realities, all in the name of love." ;
#     webSem:rated "R" ;
#     webSem:title "Amores Perros" ;
#     webSem:wasDirectedBy webSem:GuillermoArriaga ;
#     webSem:wasWrittenBy webSem:GuillermoArriaga ;
#     webSem:year "2000"^^xsd:int .
#
# webSem:Amélie a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "France, Germany" ;
#     webSem:genre "Comedy",
#         "Romance" ;
#     webSem:imdbRating "8.3"^^xsd:float ;
#     webSem:isPlayedBy webSem:AudreyTautou,
#         webSem:MathieuKassovitz,
#         webSem:Rufus ;
#     webSem:language "French, Russian, English" ;
#     webSem:overview "Amélie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love." ;
#     webSem:rated "R" ;
#     webSem:title "Amélie" ;
#     webSem:wasDirectedBy webSem:GuillaumeLaurant,
#         webSem:Jean-PierreJeunet ;
#     webSem:wasWrittenBy webSem:GuillaumeLaurant,
#         webSem:Jean-PierreJeunet ;
#     webSem:year "2001"^^xsd:int .
#
# webSem:AnAmericanWerewolfinLondon a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United Kingdom, United States" ;
#     webSem:genre "Comedy",
#         "Horror" ;
#     webSem:imdbRating "7.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:DavidNaughton,
#         webSem:JennyAgutter,
#         webSem:JoeBelcher ;
#     webSem:language "English" ;
#     webSem:overview "Two American college students on a walking tour of Britain are attacked by a werewolf that none of the locals will admit exists." ;
#     webSem:rated "R" ;
#     webSem:title "An American Werewolf in London" ;
#     webSem:wasDirectedBy webSem:JohnLandis ;
#     webSem:wasWrittenBy webSem:JohnLandis ;
#     webSem:year "1981"^^xsd:int .
#
# webSem:Anand a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "N/A" ;
#     webSem:genre "Drama",
#         "Musical" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:AmitabhBachchan,
#         webSem:RajeshKhanna,
#         webSem:SumitaSanyal ;
#     webSem:language "Hindi" ;
#     webSem:overview "The story of a terminally ill man who wishes to live life to the fullest before the inevitable occurs, as told by his best friend." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "Anand" ;
#     webSem:wasDirectedBy webSem:D.N.Mukherjee,
#         webSem:Gulzar,
#         webSem:HrishikeshMukherjee ;
#     webSem:wasWrittenBy webSem:D.N.Mukherjee,
#         webSem:Gulzar,
#         webSem:HrishikeshMukherjee ;
#     webSem:year "1971"^^xsd:int .
#
# webSem:AnandGandhi a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Anand Gandhi" .
#
# webSem:Andhadhun a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Crime",
#         "Mystery",
#         "Thriller" ;
#     webSem:imdbRating "8.2"^^xsd:float ;
#     webSem:isPlayedBy webSem:AyushmannKhurrana,
#         webSem:RadhikaApte,
#         webSem:Tabu ;
#     webSem:language "Hindi, English" ;
#     webSem:overview "A series of mysterious events change the life of a blind pianist, who must now report a crime that he should technically know nothing of." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "Andhadhun" ;
#     webSem:wasDirectedBy webSem:ArijitBiswas,
#         webSem:SriramRaghavan,
#         webSem:YogeshChandekar ;
#     webSem:wasWrittenBy webSem:ArijitBiswas,
#         webSem:SriramRaghavan,
#         webSem:YogeshChandekar ;
#     webSem:year "2018"^^xsd:int .
#
# webSem:AndreiRublev a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Soviet Union" ;
#     webSem:genre "Biography",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:AnatoliySolonitsyn,
#         webSem:IvanLapikov,
#         webSem:NikolayGrinko ;
#     webSem:language "Russian, Italian, Tatar" ;
#     webSem:overview "The life, times and afflictions of the fifteenth-century Russian iconographer St. Andrei Rublev." ;
#     webSem:rated "R" ;
#     webSem:title "Andrei Rublev" ;
#     webSem:wasDirectedBy webSem:AndreiTarkovsky,
#         webSem:AndreyKonchalovskiy ;
#     webSem:wasWrittenBy webSem:AndreiTarkovsky,
#         webSem:AndreyKonchalovskiy ;
#     webSem:year "1966"^^xsd:int .
#
# webSem:AndrewAdamson a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Andrew Adamson" .
#
# webSem:AnthonyHarvey a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Anthony Harvey" .
#
# webSem:AnthonyRusso a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Anthony Russo" .
#
# webSem:AntoineFuqua a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Antoine Fuqua" .
#
# webSem:AntonCorbijn a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Anton Corbijn" .
#
# webSem:ApocalypseNow a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Drama",
#         "Mystery",
#         "War" ;
#     webSem:imdbRating "8.5"^^xsd:float ;
#     webSem:isPlayedBy webSem:MarlonBrando,
#         webSem:MartinSheen,
#         webSem:RobertDuvall ;
#     webSem:language "English, French, Vietnamese" ;
#     webSem:overview "A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god." ;
#     webSem:rated "R" ;
#     webSem:title "Apocalypse Now" ;
#     webSem:wasDirectedBy webSem:FrancisFordCoppola,
#         webSem:JohnMilius,
#         webSem:MichaelHerr ;
#     webSem:wasWrittenBy webSem:FrancisFordCoppola,
#         webSem:JohnMilius,
#         webSem:MichaelHerr ;
#     webSem:year "1979"^^xsd:int .
#
# webSem:Apollo13 a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States, United Kingdom, Canada, Japan" ;
#     webSem:genre "Adventure",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "7.7"^^xsd:float ;
#     webSem:isPlayedBy webSem:BillPaxton,
#         webSem:KevinBacon,
#         webSem:TomHanks ;
#     webSem:language "English" ;
#     webSem:overview "NASA must devise a strategy to return Apollo 13 to Earth safely after the spacecraft undergoes massive internal damage putting the lives of the three astronauts on board in jeopardy." ;
#     webSem:rated "PG" ;
#     webSem:title "Apollo 13" ;
#     webSem:wasDirectedBy webSem:JeffreyKluger,
#         webSem:JimLovell,
#         <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#WilliamBroylesJr.> ;
#     webSem:wasWrittenBy webSem:JeffreyKluger,
#         webSem:JimLovell,
#         <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#WilliamBroylesJr.> ;
#     webSem:year "1995"^^xsd:int .
#
# webSem:Arrival a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States, Canada" ;
#     webSem:genre "Drama",
#         "Mystery",
#         "Sci-Fi" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:AmyAdams,
#         webSem:ForestWhitaker,
#         webSem:JeremyRenner ;
#     webSem:language "English, Russian, Mandarin" ;
#     webSem:overview "A linguist works with the military to communicate with alien lifeforms after twelve mysterious spacecrafts appear around the world." ;
#     webSem:rated "PG-13" ;
#     webSem:title "Arrival" ;
#     webSem:wasDirectedBy webSem:EricHeisserer,
#         webSem:TedChiang ;
#     webSem:wasWrittenBy webSem:EricHeisserer,
#         webSem:TedChiang ;
#     webSem:year "2016"^^xsd:int .
#
# webSem:ArthurPenn a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Arthur Penn" .
#
# webSem:ArthurRosson a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Arthur Rosson" .
#
# webSem:Article15 a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Crime",
#         "Drama",
#         "Mystery" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:AyushmannKhurrana,
#         webSem:ManojPahwa,
#         webSem:Nassar ;
#     webSem:language "Hindi" ;
#     webSem:overview "In the rural heartlands of India, an upright police officer sets out on a crusade against violent caste-based crimes and discrimination." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "Article 15" ;
#     webSem:wasDirectedBy webSem:AnubhavSinha,
#         webSem:GauravSolanki ;
#     webSem:wasWrittenBy webSem:AnubhavSinha,
#         webSem:GauravSolanki ;
#     webSem:year "2019"^^xsd:int .
#
# webSem:Asuran a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "India" ;
#     webSem:genre "Action",
#         "Drama" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:Dhanush,
#         webSem:ManjuWarrier,
#         webSem:PrakashRaj ;
#     webSem:language "Tamil" ;
#     webSem:overview "The teenage son of a farmer from an underprivileged caste kills a rich, upper caste landlord. Will the farmer, a loving father and a pacifist by heart, be able to save his hot-blooded son is the rest of the story." ;
#     webSem:rated "Not Rated" ;
#     webSem:title "Asuran" ;
#     webSem:wasDirectedBy webSem:M.S.Manimaran,
#         webSem:Suka,
#         webSem:Vetrimaaran ;
#     webSem:wasWrittenBy webSem:M.S.Manimaran,
#         webSem:Suka,
#         webSem:Vetrimaaran ;
#     webSem:year "2019"^^xsd:int .
#
# webSem:AutumnSonata a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "West Germany, United Kingdom" ;
#     webSem:genre "Drama",
#         "Music" ;
#     webSem:imdbRating "8.1"^^xsd:float ;
#     webSem:isPlayedBy webSem:IngridBergman,
#         webSem:LenaNyman,
#         webSem:LivUllmann ;
#     webSem:language "Swedish, English" ;
#     webSem:overview "A devoted wife is visited by her mother, a successful concert pianist who had little time for her when she was young." ;
#     webSem:rated "PG" ;
#     webSem:title "Autumn Sonata" ;
#     webSem:wasDirectedBy webSem:IngmarBergman ;
#     webSem:wasWrittenBy webSem:IngmarBergman ;
#     webSem:year "1978"^^xsd:int .
#
# webSem:Avatar a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Action",
#         "Adventure",
#         "Fantasy" ;
#     webSem:imdbRating "7.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:SamWorthington,
#         webSem:SigourneyWeaver,
#         webSem:ZoeSaldana ;
#     webSem:language "English, Spanish" ;
#     webSem:overview "A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home." ;
#     webSem:rated "PG-13" ;
#     webSem:title "Avatar" ;
#     webSem:wasDirectedBy webSem:JamesCameron ;
#     webSem:wasWrittenBy webSem:JamesCameron ;
#     webSem:year "2009"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Avengers:Endgame> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Action",
#         "Adventure",
#         "Drama" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChrisEvans,
#         webSem:MarkRuffalo,
#         <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#RobertDowneyJr.> ;
#     webSem:language "English, Japanese, Xhosa, German" ;
#     webSem:overview "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe." ;
#     webSem:rated "PG-13" ;
#     webSem:title "Avengers: Endgame" ;
#     webSem:wasDirectedBy webSem:ChristopherMarkus,
#         webSem:StanLee,
#         webSem:StephenMcFeely ;
#     webSem:wasWrittenBy webSem:ChristopherMarkus,
#         webSem:StanLee,
#         webSem:StephenMcFeely ;
#     webSem:year "2019"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Avengers:InfinityWar> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "United States" ;
#     webSem:genre "Action",
#         "Adventure",
#         "Sci-Fi" ;
#     webSem:imdbRating "8.4"^^xsd:float ;
#     webSem:isPlayedBy webSem:ChrisHemsworth,
#         webSem:MarkRuffalo,
#         <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#RobertDowneyJr.> ;
#     webSem:language "English" ;
#     webSem:overview "The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe." ;
#     webSem:rated "PG-13" ;
#     webSem:title "Avengers: Infinity War" ;
#     webSem:wasDirectedBy webSem:ChristopherMarkus,
#         webSem:StanLee,
#         webSem:StephenMcFeely ;
#     webSem:wasWrittenBy webSem:ChristopherMarkus,
#         webSem:StanLee,
#         webSem:StephenMcFeely ;
#     webSem:year "2018"^^xsd:int .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Ayla:TheDaughterofWar> a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "Turkey" ;
#     webSem:genre "Biography",
#         "Drama",
#         "History" ;
#     webSem:imdbRating "8.3"^^xsd:float ;
#     webSem:isPlayedBy webSem:IsmailHacioglu,
#         webSem:Kyung-jinLee,
#         webSem:ÇetinTekindor ;
#     webSem:language "Turkish, Korean, English, Chinese" ;
#     webSem:overview "In 1950, amidst the ravages of the Korean War, Sergeant Süleyman stumbles upon a half-frozen little girl with no parents, and no help in sight. Frantic, scared and on the verge of death, this little girl captures the heart of Süle..." ;
#     webSem:rated "N/A" ;
#     webSem:title "Ayla: The Daughter of War" ;
#     webSem:wasDirectedBy webSem:YigitGüralp ;
#     webSem:wasWrittenBy webSem:YigitGüralp ;
#     webSem:year "2017"^^xsd:int .
#
# webSem:BTime2 a webSem:BroadcastTime,
#         owl:NamedIndividual ;
#     webSem:endDate "2023-03-20T00:00:00"^^xsd:dateTime ;
# ...
#     webSem:name "Michael Lewis" .
#
# webSem:MorganFreeman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Morgan Freeman" .
#
# webSem:NeerajPandey a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Neeraj Pandey" .
#
# webSem:NicholasPileggi a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Nicholas Pileggi" .
#
# webSem:NikhilMehrotra a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Nikhil Mehrotra" .
#
# webSem:ParkChan-wook a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Park Chan-wook" .
#
# webSem:PaulHaggis a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Paul Haggis" .
#
# webSem:PaulNewman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Paul Newman" .
#
# webSem:PhilipK.Dick a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Philip K. Dick" .
#
# webSem:PierreBoulle a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Pierre Boulle" .
#
# webSem:PiyushGupta a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Piyush Gupta" .
#
# webSem:PulpFiction a webSem:Movie,
#         owl:NamedIndividual ;
#     webSem:country "USA",
#         "United States" ;
#     webSem:genre "Crime",
#         "Drama",
#         "Thriller" ;
#     webSem:imdbRating "8.9"^^xsd:float ;
#     webSem:isPlayedBy webSem:JohnTravolta,
#         webSem:SamuelL.Jackson,
#         webSem:UmaThurman ;
#     webSem:isProjectedAt webSem:UGCLaDefense ;
#     webSem:language "English",
#         "English, Spanish, French" ;
#     webSem:overview "The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption." ;
#     webSem:rated "R" ;
#     webSem:title "Pulp Fiction" ;
#     webSem:wasDirectedBy webSem:QuentinTarantino,
#         webSem:RogerAvary ;
#     webSem:wasWrittenBy webSem:QuentinTarantino,
#         webSem:RogerAvary ;
#     webSem:year "1994"^^xsd:int .
#
# webSem:RajkumarHirani a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Rajkumar Hirani" .
#
# webSem:RaymondChandler a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Raymond Chandler" .
#
# webSem:ReemaKagti a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Reema Kagti" .
#
# webSem:RichardBrooks a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Richard Brooks" .
#
# webSem:RichardLinklater a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Richard Linklater" .
#
# webSem:RiteshShah a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ritesh Shah" .
#
# webSem:RoaldDahl a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Roald Dahl" .
#
# webSem:RobertBolt a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert Bolt" .
#
# <http://www.semanticweb.org/marya/ontologies/2023/2/webSem#RobertDowneyJr.> a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert Downey Jr." .
#
# webSem:RobertDuvall a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert Duvall" .
#
# webSem:RobertE.Sherwood a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert E. Sherwood" .
#
# webSem:RobertZemeckis a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert Zemeckis" .
#
# webSem:RogerAvary a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Roger Avary" .
#
# webSem:SaurabhM.Pandey a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Saurabh M. Pandey" .
#
# webSem:ScottSilver a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Scott Silver" .
#
# webSem:SergioDonati a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Sergio Donati" .
#
# webSem:StephenMcFeely a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Stephen McFeely" .
#
# webSem:SteveConrad a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Steve Conrad" .
#
# webSem:SteveKloves a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Steve Kloves" .
#
# webSem:SushantSinghRajput a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Sushant Singh Rajput" .
#
# webSem:TaylorSheridan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Taylor Sheridan" .
#
# webSem:TedSears a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ted Sears" .
#
# webSem:TerryGeorge a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Terry George" .
#
# webSem:TerryRossio a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Terry Rossio" .
#
# webSem:TheavonHarbou a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Thea von Harbou" .
#
# webSem:ThomasNarcejac a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Thomas Narcejac" .
#
# webSem:TomCruise a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Tom Cruise" .
#
# webSem:TomHardy a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Tom Hardy" .
#
# webSem:TomMcCarthy a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Tom McCarthy" .
#
# webSem:TommMoore a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Tomm Moore" .
#
# webSem:UmaThurman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:age "43"^^xsd:int ;
#     webSem:isActorOf webSem:PulpFiction ;
#     webSem:isWriterOf webSem:KillBill ;
#     webSem:name "Uma Thurman" .
#
# webSem:VeraMiles a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Vera Miles" .
#
# webSem:VivekAgnihotri a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Vivek Agnihotri" .
#
# webSem:W.R.Burnett a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "W.R. Burnett" .
#
# webSem:WilhelmGrimm a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Wilhelm Grimm" .
#
# webSem:WillCollins a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Will Collins" .
#
# webSem:WilliamHolden a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "William Holden" .
#
# webSem:WilliamNicholson a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "William Nicholson" .
#
# webSem:WilliamWisher a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "William Wisher" .
#
# webSem:WillisGoldbeck a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Willis Goldbeck" .
#
# webSem:ZoyaAkhtar a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Zoya Akhtar" .
#
# webSem:AlPacino a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Al Pacino" .
#
# webSem:BenAffleck a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ben Affleck" .
#
# webSem:EthanHawke a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ethan Hawke" .
#
# webSem:EwanMcGregor a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ewan McGregor" .
#
# webSem:HughJackman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Hugh Jackman" .
#
# webSem:JamesStewart a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "James Stewart" .
#
# webSem:JoaquinPhoenix a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Joaquin Phoenix" .
#
# webSem:JulieDelpy a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Julie Delpy" .
#
# webSem:KurtRussell a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Kurt Russell" .
#
# webSem:RobertRedford a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert Redford" .
#
# webSem:TatsuyaNakadai a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Tatsuya Nakadai" .
#
# webSem:ToshirôMifune a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Toshirô Mifune" .
#
# webSem:AamirKhan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Aamir Khan" .
#
# webSem:AaronSorkin a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Aaron Sorkin" .
#
# webSem:AnthonyHopkins a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Anthony Hopkins" .
#
# webSem:BradBird a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Brad Bird" .
#
# webSem:BroadcastTime a owl:Class ;
#     owl:disjointWith webSem:Person .
#
# webSem:CemYilmaz a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Cem Yilmaz" .
#
# webSem:ChrisSanders a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Chris Sanders" .
#
# webSem:DavidS.Goyer a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "David S. Goyer" .
#
# webSem:DavidWebbPeoples a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "David Webb Peoples" .
#
# webSem:EdgarWright a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Edgar Wright" .
#
# webSem:EricRoth a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Eric Roth" .
#
# webSem:ErnestLehman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ernest Lehman" .
#
# webSem:FarhanAkhtar a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Farhan Akhtar" .
#
# webSem:FranWalsh a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Fran Walsh" .
#
# webSem:FrancisFordCoppola a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Francis Ford Coppola" .
#
# webSem:GrahamChapman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Graham Chapman" .
#
# webSem:J.R.R.Tolkien a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "J.R.R. Tolkien" .
#
# webSem:JamesM.Cain a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "James M. Cain" .
#
# webSem:JohnCleese a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "John Cleese" .
#
# webSem:JohnLasseter a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "John Lasseter" .
#
# webSem:JohnMusker a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "John Musker" .
#
# webSem:JulesFurthman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Jules Furthman" .
#
# webSem:KrzysztofKieslowski a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Krzysztof Kieslowski" .
#
# webSem:KrzysztofPiesiewicz a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Krzysztof Piesiewicz" .
#
# webSem:LawrenceKasdan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Lawrence Kasdan" .
#
# webSem:LucianoVincenzoni a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Luciano Vincenzoni" .
#
# webSem:MichaelWilson a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Michael Wilson" .
#
# webSem:OliverStone a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Oliver Stone" .
#
# webSem:PeterMorgan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Peter Morgan" .
#
# webSem:PhilipKaufman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Philip Kaufman" .
#
# webSem:PhilippaBoyens a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Philippa Boyens" .
#
# webSem:PierreBoileau a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Pierre Boileau" .
#
# webSem:RomanPolanski a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Roman Polanski" .
#
# webSem:RonClements a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ron Clements" .
#
# webSem:RussellCrowe a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Russell Crowe" .
#
# webSem:RyûzôKikushima a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ryûzô Kikushima" .
#
# webSem:ShahRukhKhan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Shah Rukh Khan" .
#
# webSem:StanLee a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Stan Lee" .
#
# webSem:StevenZaillian a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Steven Zaillian" .
#
# webSem:TedElliott a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ted Elliott" .
#
# webSem:WesAnderson a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Wes Anderson" .
#
# webSem:WilliamFaulkner a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "William Faulkner" .
#
# webSem:WilliamGoldman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "William Goldman" .
#
# webSem:HumphreyBogart a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Humphrey Bogart" .
#
# webSem:KevinCostner a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Kevin Costner" .
#
# webSem:LeonardoDiCaprio a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Leonardo DiCaprio" .
#
# webSem:AndreiTarkovsky a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Andrei Tarkovsky" .
#
# webSem:AndrewStanton a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Andrew Stanton" .
#
# webSem:BenHecht a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ben Hecht" .
#
# webSem:HarrisonFord a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Harrison Ford" .
#
# webSem:IngmarBergman a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ingmar Bergman" .
#
# webSem:JamesCameron a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "James Cameron" .
#
# webSem:JohnWayne a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "John Wayne" .
#
# webSem:LeighBrackett a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Leigh Brackett" .
#
# webSem:MattDamon a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Matt Damon" .
#
# webSem:SergioLeone a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Sergio Leone" .
#
# webSem:StephenKing a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Stephen King" .
#
# webSem:Theater a owl:Class .
#
# webSem:BradPitt a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Brad Pitt" .
#
# webSem:ChristianBale a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Christian Bale" .
#
# webSem:ClintEastwood a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Clint Eastwood" .
#
# webSem:JohnHuston a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "John Huston" .
#
# webSem:RobertDeNiro a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Robert De Niro" .
#
# webSem:SylvesterStallone a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Sylvester Stallone" .
#
# webSem:TomHanks a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Tom Hanks" .
#
# webSem:GeorgeLucas a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "George Lucas" .
#
# webSem:HideoOguni a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Hideo Oguni" .
#
# webSem:JonathanNolan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Jonathan Nolan" .
#
# webSem:ShinobuHashimoto a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Shinobu Hashimoto" .
#
# webSem:EthanCoen a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Ethan Coen" .
#
# webSem:JoelCoen a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Joel Coen" .
#
# webSem:QuentinTarantino a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:age "53"^^xsd:int ;
#     webSem:isActorOf webSem:KillBill ;
#     webSem:isDirectorOf webSem:KillBill,
#         webSem:PulpFiction ;
#     webSem:isWriterOf webSem:KillBill,
#         webSem:PulpFiction ;
#     webSem:name "Quentin Tarantino" ;
#     webSem:nationality "American" .
#
# webSem:OrsonWelles a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Orson Welles" .
#
# webSem:BillyWilder a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Billy Wilder" .
#
# webSem:PeteDocter a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Pete Docter" .
#
# webSem:AkiraKurosawa a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Akira Kurosawa" .
#
# webSem:ChristopherNolan a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Christopher Nolan" .
#
# webSem:HayaoMiyazaki a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Hayao Miyazaki" .
#
# webSem:StanleyKubrick a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Stanley Kubrick" .
#
# webSem:CharlesChaplin a webSem:Person,
#         owl:NamedIndividual ;
#     webSem:name "Charles Chaplin" .
#
# webSem:Movie a owl:Class ;
#     owl:disjointWith webSem:Person,
#         webSem:Theater .
#
# webSem:Person a owl:Class ;
#     owl:disjointWith webSem:Theater .

# %%
webSem = Namespace("http://www.semanticweb.org/marya/ontologies/2023/2/webSem#")

# %%
for s, p, o in g.triples((None, RDF.type, webSem.Person)):
    print(f"{s} is a person")
# Out:
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#A.B.GuthrieJr. is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#A.B.JawdatEl-Sahhar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#A.E.Southon is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AamilKeeyanKhan is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AamirKhan is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AaronCovington is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AaronEckhart is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AaronGuzikowski is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AaronSorkin is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbbasAlibhaiBurmawalla is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbburiRavi is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbbyMann is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbhayDeol is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbhijatJoshi is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbhishekKapoor is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbhishekPathak is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AbrahamMarder is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AchyuthKumar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdamElliot is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdamMcKay is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdeshPrasad is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdithyaBhaskar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdityaChopra is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdityaDhar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdityaNimbalkar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdiviSesh is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdnanAdibKhan is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdolphGreen is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdolpheMenjou is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdrianMolina is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdrianaCaselotti is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdrianoBolzoni is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdrienBrody is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdvaitChandan is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdvaitaKala is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AdèleHaenel is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AgathaChristie is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AgenoreIncrocci is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AgnieszkaHolland is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AgustínAlmodóvar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AhmedMourad is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AidanGillen is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AidanQuinn is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AjayDevgn is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkariKitô is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkashKhurana is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkemiYamaguchi is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkhileshJaiswal is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkioÔtsuka is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkiraIshihama is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkiraKurosawa is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkiraTerao is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkivaGoldsman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkiyukiNosaka is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkshayKumar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AkshayeKhanna is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlBoasberg is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlErnestGarcia is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlPacino is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlainBoublil is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlainDelon is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanBall is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanJ.Pakula is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanJayLerner is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanLadd is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanLeMay is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanMak is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanParker is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanRickman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlanTudyk is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlbertBrooks is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlbertFinney is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlbertHackett is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlbertRémy is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlecCoppel is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlecGuinness is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlejandroAmenábar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlejandroG.Iñárritu is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AleksandrAntonov is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AleksandrKaydanovskiy is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AleksandrMisharin is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlekseyKravchenko is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlesAdamovich is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlessandroBaricco is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlexGarland is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlexProyas is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#AlexSharp is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#A
a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ChristopherPlummer is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ChristopherPriest is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ChristopherWalken is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ChuckPalahniuk is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ChungSeo-kyung is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CiaránHinds is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CillianMurphy is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CindyDavis is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClaireForlani is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClaireMaurier is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClaireTrevor is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClancyBrown is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClarkCheng is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClarkGable is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Claude-MichelSchönberg is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClaudeRains is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClaudetteColbert is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClaudiaCardinale is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CleavonLittle is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CliffDorfman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CliffHollingsworth is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CliffordOdets is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CliftonWebb is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClintEastwood is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ClydeBruckman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ColeenGray is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ColinClive is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ColinFirth is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ColmFeore is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ColmMeaney is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ConnieNielsen is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ConradVeidt is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CoreyFeldman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CoreyHawkins is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CoriGonzalez-Macuer is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CormacMcCarthy is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CornellWoolrich is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Costa-Gavras is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CraigBierko is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CraigGillespie is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CraigParkinson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CraigPearce is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CraigStorper is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CraigT.Nelson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CressidaCowell is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CrispinGlover is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CubaGoodingJr. is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CurtisHanson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CybillShepherd is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CzenziOrmonde is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#CélineSciamma is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#D.M.MarshmanJr. is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#D.N.Mukherjee is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DafneKeen is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DalipTahil is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DaltonTrumbo is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DamienChazelle is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DamiánSzifron is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanAbnett is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanAykroyd is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanFogelman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanHicks is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanKwan is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanaAndrews is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanaWynter is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielBrühl is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielCraig is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielDay-Lewis is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielGerson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielKaluuya is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielMainwaring is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielMays is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielRadcliffe is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielScheinert is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DanielWallace is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DannyBoyle is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DannyElfman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DannyGlover is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DannyLloyd is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DannyRubin is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DannyTrejo is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DaphneDuMaurier is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DarioArgento is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DariusMarder is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DarrenAronofsky is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DarshanKumaar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DarsheelSafary is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DarylHannah is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DaríoGrandinetti is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DashiellHammett is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DaveGoelz is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DaveJohannson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DaveighChase is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidAnspaugh is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidBradley is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidCarradine is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidCronenberg is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidEmge is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidFincher is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidFranzoni is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidGiler is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidHand is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidJ.Schow is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidKoepp is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidLean is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidLloyd is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidLynch is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidMackenzie is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidMcKenna is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidMickeyEvans is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidMorse is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidNaughton is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidO.Russell is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidPeace is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidRawle is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidReynolds is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidRoper is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidS.Goyer is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidS.Ward is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidSeidler is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidSeltzer is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidSilverman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidStone is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidTomlinson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidWebbPeoples is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavidYates is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavisGrubb is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DavorDujmovic is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Dean-CharlesChapman is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeanDeBlois is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeanMartin is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeanRiesner is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DebbieReynolds is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeborahCurtis is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeborahKaraUnger is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeborahKerr is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DebraHill is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeclaDunning is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeemsTaylor is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DeepikaPadukone is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DelleBolton is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DemetEvgar is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DenisVilleneuve is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DennisHopper is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DennisLehane is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DennisShryack is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DenzelWashington is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DerekCianfrance is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DerekHaas is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DericWashburn is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DevPatel is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DexterFletcher is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Dhanush is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Dharmendra is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DianaWynneJones is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DianeJohnson is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#DianeKruger is a person
# ...
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#ValérieBeaugrand-Champagne is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VanHeflin is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VanceGerry is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VannaPaoli is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VardisFisher is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VarunSharma is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VasanBala is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VassilisVassilikos is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VeerendraSaxena is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VeerleBaetens is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VeraCaspary is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VeraFarmiga is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VeraMiles is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VernaBloom is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VernonDobtcheff is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#
a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#IleanaD'Cruz is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#JamesO'Barr is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#JudithO'Dea is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Ken'ichiHagiwara is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#N/A is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#O'SheaJacksonJr. is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#PaigeO'Hara is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#PeterO'Toole is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Predrag'Miki'Manojlovic is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Rubin'Hurricane'Carter is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#RyanO'Neal is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Shin'ichiHimori is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#Shin'ichirôUeda is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#SusoCecchiD'Amico is a person
# http://www.semanticweb.org/marya/ontologies/2023/2/webSem#VincentD'Onofrio is a person

# %% [markdown]
# Loads the ontology and displays all the Persons (using a query, without inference). Create the used query in text file under the data folder.

# %%
qres = g.query("""
                SELECT ?name
                    WHERE { ?x rdf:type webSem:Person.
                             # ?x  webSem:name ?name }
                """)

print(f"Number of persons : {len(qres)}")
for row in qres:
    print(f"{row.name}")
# Out:
# Number of persons : 2611
# A.B. Guthrie Jr.
# A.B. Jawdat El-Sahhar
# A.E. Southon
# Aamil Keeyan Khan
# Aamir Khan
# Aaron Covington
# Aaron Eckhart
# Aaron Guzikowski
# Aaron Sorkin
# Abbas Alibhai Burmawalla
# Abburi Ravi
# Abby Mann
# Abhay Deol
# Abhijat Joshi
# Abhishek Kapoor
# Abhishek Pathak
# Abraham Marder
# Achyuth Kumar
# Adam Elliot
# Adam McKay
# Adesh Prasad
# Adithya Bhaskar
# Aditya Chopra
# Aditya Dhar
# Aditya Nimbalkar
# Adivi Sesh
# Adnan Adib Khan
# Adolph Green
# Adolphe Menjou
# Adrian Molina
# Adriana Caselotti
# Adriano Bolzoni
# Adrien Brody
# Advait Chandan
# Advaita Kala
# Adèle Haenel
# Agatha Christie
# Agenore Incrocci
# Agnieszka Holland
# Agustín Almodóvar
# Ahmed Mourad
# Aidan Gillen
# Aidan Quinn
# Ajay Devgn
# Akari Kitô
# Akash Khurana
# Akemi Yamaguchi
# Akhilesh Jaiswal
# Akio Ôtsuka
# Akira Ishihama
# Akira Kurosawa
# Akira Terao
# Akiva Goldsman
# Akiyuki Nosaka
# Akshay Kumar
# Akshaye Khanna
# Al Boasberg
# Al Ernest Garcia
# Al Pacino
# Alain Boublil
# Alain Delon
# Alan Ball
# Alan J. Pakula
# Alan Jay Lerner
# Alan Ladd
# Alan Le May
# Alan Mak
# Alan Parker
# Alan Rickman
# Alan Tudyk
# Albert Brooks
# Albert Finney
# Albert Hackett
# Albert Rémy
# Alec Coppel
# Alec Guinness
# Alejandro Amenábar
# Alejandro G. Iñárritu
# Aleksandr Antonov
# Aleksandr Kaydanovskiy
# Aleksandr Misharin
# Aleksey Kravchenko
# Ales Adamovich
# Alessandro Baricco
# Alex Garland
# Alex Proyas
# Alex Sharp
# Alexa Demie
# Alexander Gould
# Alexander Granach
# Alexander Korda
# Alexander Mackendrick
# Alexandra Maria Lara
# Alexandra Shipp
# Alexandre Rodrigues
# Alfonso Cuarón
# Alfred Abel
# Alfred Hitchcock
# Ali Suliman
# Alia Bhatt
# Alida Valli
# Alisa Freyndlikh
# Alison Crosbie
# Alison Doody
# Allison Janney
# Allison Schroeder
# Allison Williams
# Alma Reville
# Alok Jha
# Alun Owen
# Rubin 'Hurricane' Carter
# Ryan O'Neal
# Shin'ichi Himori
# Shin'ichirô Ueda
# Suso Cecchi D'Amico
# Vincent D'Onofrio

# %%
for s, p, o in g.triples((None, RDF.type, webSem.Actor)):
    print(f"{s} is an Actor")

# %% [markdown]
# Loads the ontology and displays all the Actors (without using queries, using inference).

# %%
onto = get_ontology("file://projetowl.owl").load()

# %%
list(onto.classes())
# Out:
# [projetowl.Actor,
#  projetowl.BroadcastTime,
#  projetowl.Director,
#  projetowl.Movie,
#  projetowl.Person,
#  projetowl.Theater,
#  projetowl.Writer]

# %% [markdown]
# Develops a program that :
# - Reads a name of a movie
# - If it doesn’t exist displays an error message
# - Else, display its year, country, genres and actors
# - Display their program where and when

# %%
qres = g.query("""SELECT ?title WHERE { ?x webSem:title "Kill Bill". ?x  webSem:title ?title}""")
    
for row in qres:
    print(f"{row.title}")
# Out:
# Kill Bill

# %%
def searchMovie(name):
    qres = g.query(f"SELECT ?title WHERE {{ ?x webSem:title {name}. ?x  webSem:title ?title}}")
    
    for row in qres:
        print(f"{row}")

# %%
searchMovie("Kill Bill")
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 searchMovie("Kill Bill")
#
# Input In [57], in searchMovie(name)
#       1 def searchMovie(name):
# ----> 2     qres = g.query(f"SELECT ?title WHERE {{ ?x webSem:title {name}. ?x  webSem:title ?title}}")
#       4     for row in qres:
#       5         print(f"{row}")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\rdflib\graph.py:1389, in Graph.query(self, query_object, processor, result, initNs, initBindings, use_store_provided, **kwargs)
#    1386 if not isinstance(processor, query.Processor):
#    1387     processor = plugin.get(processor, query.Processor)(self)
# -> 1389 return result(processor.query(query_object, initBindings, initNs, **kwargs))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\processor.py:77, in SPARQLProcessor.query(self, strOrQuery, initBindings, initNs, base, DEBUG)
#      70 """
#      71 Evaluate a query with the given initial bindings, and initial
#      72 namespaces. The given base is used to resolve relative URIs in
#      73 the query and will be overridden by any BASE given in the query.
#      74 """
#      76 if not isinstance(strOrQuery, Query):
# ---> 77     parsetree = parseQuery(strOrQuery)
#      78     query = translateQuery(parsetree, base, initNs)
#      79 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\rdflib\plugins\sparql\parser.py:1536, in parseQuery(q)
#    1533     q = q.decode("utf-8")
#    1535 q = expandUnicodeEscapes(q)
# -> 1536 return Query.parseString(q, parseAll=True)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:1107, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1104         raise
#    1105     else:
#    1106         # catch and re-raise exception from here, clearing out pyparsing internal stack trace
# -> 1107         raise exc.with_traceback(None)
#    1108 else:
#    1109     return tokens
#
# ParseException: Expected {SelectQuery | ConstructQuery | DescribeQuery | AskQuery}, found '?'  (at char 22), (line:1, col:23)

# %% [markdown]
# Displays all persons that are actors and directors. Do this using a rule that defines a new class ActorDirector. The rule file must be saved in the data folder.

# %% [markdown]
# Specifies 3 different rules and implement them in a java program
